# %% [markdown]
# # NOTES:

# %%
import pandas as pd

# %%
out = []

for x in range(0,12,2):
    out.append(x**2)

    print(out)
# Out:
# [0]
# [0, 4]
# [0, 4, 16]
# [0, 4, 16, 36]
# [0, 4, 16, 36, 64]
# [0, 4, 16, 36, 64, 100]

# %%
out = []

for x in range(0,12,2):
    out.append(x**2)

print(out)
# Out:
# [0, 4, 16, 36, 64, 100]

# %%
[ x**2 for x in range(12) if x%2==0]
# Out:
# [0, 4, 16, 36, 64, 100]

# %%
[ x*2 for x in range(0,12,2) if x**2]
# Out:
# [4, 8, 12, 16, 20]

# %%
[ x for x in range(0,12,2) if x**2]
# Out:
# [2, 4, 6, 8, 10]

# %%
[ x*2 for x in range(0,12,2) ]
# Out:
# [0, 4, 8, 12, 16, 20]

# %%
file_path = r'C:\Users\1_2ta\Documents\py\data\testing.csv'
data = pd.read_csv(file_path)
# Out:
#      class  max_ndvi  20150720_N  20150602_N  20150517_N  20150501_N  \
# 0    water  2750.110   1361.8900    -247.508  -521.17300   -1123.910
# 1    water  2646.250   1760.8500     481.100     6.26571     398.950
# 2    water  3509.620   3509.6200    -241.320 -1239.32000    -330.388
# 3    water  2820.470   2138.6900    -126.186  -522.28100    -741.163
# 4    water  2684.130   1995.8000   -1029.570  1713.62000    -472.258
# ..     ...       ...         ...         ...         ...         ...
# 295  water   491.678  -1673.7400   -2514.480 -2451.19000   -2738.440
# 296  water   556.093    -96.8233    -412.727 -1795.40000   -2363.820
# 297  water   987.461  -2364.6000    -155.592 -1422.09000   -1713.400
# 298  water   973.953  -3004.6300   -1217.120   180.12200   -1113.890
# 299  water   516.427  -2975.1000   -1129.790   463.74800   -5355.400
#
#      20150415_N  20150330_N  20150314_N  20150226_N  ...  20140610_N  \
# ...

# %%
file_path = r'C:\Users\1_2ta\Documents\py\data\training.csv'
data = pd.read_csv(file_path)
print(data)
# Out:
#             class  max_ndvi  20150720_N  20150602_N  20150517_N  20150501_N  \
# 0           water   997.904    637.5950     658.668   -1882.030    -1924.36
# 1           water   914.198    634.2400     593.705   -1625.790    -1672.32
# 2           water  3800.810   1671.3400    1206.880     449.735     1071.21
# 3           water   952.178     58.0174   -1599.160     210.714    -1052.63
# 4           water  1232.120     72.5180   -1220.880     380.436    -1256.93
# ...           ...       ...         ...         ...         ...         ...
# 10540  impervious  7579.580   6072.5000    3803.140    3902.220     3897.43
# 10541  impervious  2780.930   1895.6800    1454.740    1265.480     1033.56
# 10542  impervious  5833.760   3465.7400    1283.320     413.412     4391.05
# 10543  impervious  3079.310   2435.3000    1444.400    1133.760     1278.74
# 10544  impervious  7352.570   6941.1900    1667.870    5084.780     4832.13
#
# ...

# %%
# file_path = '../data/uscg.search.rescue.stats.csv'
# pd.read_csv(file_path)

# %% [markdown]
# ## **Creating DataFrames
# > 1. use the dictionary data to create a DataFrame

# %%
data = { 'col1': ['v1', 'v2', 'v3'],
        'col2': [0, 1, 2]}

# %% [markdown]
# > Use this list of lists to create a DataFrame

# %%
data = [['v1', 0],
        ['v2', 1],
        ['v3', 2]]
